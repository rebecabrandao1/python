# %% [markdown]
# <a href="https://colab.research.google.com/github/rebecabrandao1/python/blob/master/renew.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importando bibliotecas
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import numpy as np
import pandas as pd
from matplotlib import cm
from IPython.display import clear_output

# %%
#carregando dados do wine dataset

# %%
data = pd.read_csv (
    'https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data',
    header=None
)

# %%
#Atribuindo títulos ás colunas

# %%
data.columns = [
    'Quality',
    'Alcohol',
    'Malic acid',
    'Ash',
    'Alcalinity of ash',
    'Magnesium',
    'Total phenols',
    'Flavanoids',
    'Nonflavanoid phenols',
    'Proanthocyanins',
    'Color intensity',
    'Hue',
    'OD280/OD315 of diluted wines',
    'Proline',               
]

# %%
#visualizando as 6 primeiras linhas

# %%
data.head(6)
# Out:
#    Quality  Alcohol  Malic acid  ...   Hue  OD280/OD315 of diluted wines  Proline
# 0        1    14.23        1.71  ...  1.04                          3.92     1065
# 1        1    13.20        1.78  ...  1.05                          3.40     1050
# 2        1    13.16        2.36  ...  1.03                          3.17     1185
# 3        1    14.37        1.95  ...  0.86                          3.45     1480
# 4        1    13.24        2.59  ...  1.04                          2.93      735
# 5        1    14.20        1.76  ...  1.05                          2.85     1450
#
# [6 rows x 14 columns]

# %%
#filtrando dados

# %%
data = data[data['Quality']!=1]

data['Quality'].value_counts()
# Out:
# 2    71
# 3    48
# Name: Quality, dtype: int64

# %%
#escolhendo o que plotar
sns.pairplot(
    data,
    hue="Quality",
    vars=[
        d for d in data.columns if d!='Quality'
    ]
)

# %%
# filtro: 4 variáveis
data = data[[
    'Quality',
    'OD280/OD315 of diluted wines',
    'Hue',
    'Proline'
]]

# %%
# cria a janela da figura
fig = plt.figure()

# carrega os eixos criando um a mais se necessário
ax = fig.gca(projection='3d')

# cria lista de cor considerando qualidade
colors = data['Quality'].map({2:'g',3:'r'}).values

# cria o gráfico
ax.scatter(
    data['OD280/OD315 of diluted wines'],
    data['Hue'],
    data['Proline'],
    c=colors
)

# ajusta e mostra o gráfico
plt.tight_layout()
plt.show()

# %%
# cria a janela da figura
fig = plt.figure()

# carrega os eixos criando um a mais se necessário
ax = fig.gca(projection='3d')

# cria lista de cor considerando qualidade
colors = data['Quality'].map({2:'g',3:'r'}).values

# cria o gráfico
ax.scatter(
    data['OD280/OD315 of diluted wines'],
    data['Hue'],
    data['Proline'],
    c=colors
)

# Nomeia os eixos
plt.title("Qualidade do vinho")
plt.xlabel('OD280/OD315 of diluted wines')
plt.ylabel('Hue')
ax.set_zlabel('Proline')

# configura legendas
legend_elements = [
    Line2D([0], [0],
        marker='o',
        color='w',
        label='Bom',
        markerfacecolor='g',
        markersize=10
    ),
    Line2D(
        [0], [0],
        marker='o',
        color='w',
        label='Ruim',
        markerfacecolor='r',
        markersize=10
    )
]
                   
# cria legendas
ax.legend(handles=legend_elements, loc='best')



plt.tight_layout()
plt.show()

# %%
for angle in range(30,330,2):

    # faz o gráfico
    fig = plt.figure()
    ax = fig.gca(projection='3d')
    ax.scatter(
        data['OD280/OD315 of diluted wines'],
        data['Hue'],
        data['Proline'],
        color=colors)
    
    # configura o ângulo
    ax.view_init(30,angle)
    
    # mostra
    plt.tight_layout()
    plt.gca()
    clear_output(wait=True)
    plt.show()

# %%
for angle in range(30,330,2):

    # Make the plot
    fig = plt.figure()
    ax = fig.gca(projection='3d')
    ax.scatter(
        data['OD280/OD315 of diluted wines'],
        data['Hue'],
        data['Proline'],
        )
    
    # Set the view
    ax.view_init(30,angle)
    
    # Set labels
    plt.title('Quality of wines')
    plt.xlabel('OD280/OD315 of diluted wines')
    plt.ylabel('Hue')
    ax.set_zlabel('Proline')

    # save plots
    filename='wine'+str(angle)+'.png'
    plt.savefig(filename, dpi=96)
    
    # Create customized legends 
    legend_elements = [
        Line2D([0], [0], marker='o', color='w', label='Bom',markerfacecolor='g', markersize=10),
        Line2D([0], [0], marker='o', color='w', label='Ruim',markerfacecolor='r', markersize=10)
    ]

    # Make legend
    ax.legend(handles=legend_elements, loc='best')
    plt.tight_layout()
    plt.gca()
    clear_output(wait=True)
    plt.show()
